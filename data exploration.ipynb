# %% [markdown]
# # You are given a dataset, which is present in the LMS, containing the number of hurricanes occurring in the United States along the coast of the Atlantic. Load the data from the dataset into your program and plot a Bar Graph of the data, taking the Year as the x-axis and the number of hurricanes occurring as the Y-axis.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('dataset/Hurricanes.csv')

# %%
data
# Out:
#      Year  Hurricanes
# 0    1914           0
# 1    1915           5
# 2    1916          10
# 3    1917           2
# 4    1918           4
# ..    ...         ...
# 96   2010          12
# 97   2011           7
# 98   2012          10
# 99   2013           2
# 100  2014           6
#
# [101 rows x 2 columns]

# %%
plt.bar(data['Year'],data['Hurricanes'])
plt.ylabel('no of hurricanes')
plt.xlabel('year')
# Out:
# Text(0.5, 0, 'year')

# %% [markdown]
# # The dataset given, records data of city temperatures over the years 2014 and 2015. Plot the histogram of the temperatures over this period for the cities of San Francisco and Moscow.

# %%
city_data = pd.read_csv('dataset/CityTemps.csv')

# %%
city_data
# Out:
#     Year  Month  Moscow  Melbourne  San Francisco
# 0   2014      1    -8.6       22.0           12.8
# 1   2014      2    -1.9       21.5           12.7
# 2   2014      3     2.8       19.5           15.0
# 3   2014      4     7.0       15.8           15.7
# 4   2014      5    16.0       13.9           17.5
# 5   2014      6    16.1       11.3           17.9
# 6   2014      7    21.1        9.9           19.4
# 7   2014      8    19.2       10.4           19.5
# 8   2014      9    12.3       12.8           20.2
# 9   2014     10     3.7       15.6           20.4
# 10  2014     11    -1.3       17.3           15.4
# 11  2014     12    -3.9       18.9           13.8
# 12  2015      1    -4.4       20.4           12.2
# 13  2015      2    -2.2       21.8           14.8
# 14  2015      3     2.0       17.4           15.7
# 15  2015      4     6.1       14.1           14.8
# 16  2015      5    14.2       12.6           14.7
# 17  2015      6    17.9        9.8           17.1
# ...

# %%
city_MS = city_data.loc[:,['Melbourne','San Francisco']]
city_MS.hist(density = True, histtype = 'bar', color = 'blue')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa93b7504f0>,
# ...
#       dtype=object)

# %% [markdown]
# # Plot a pie-chart of the number of models released by every manufacturer, recorded in the data provide. Also mention the name of the manufacture with the largest releases.

# %%
cars = pd.read_csv('dataset/Cars2015.csv')

# %%
cars
# Out:
#            Make       Model       Type  LowPrice  HighPrice Drive  CityMPG  \
# 0     Chevrolet       Spark  Hatchback    12.270     25.560   FWD       30
# 1       Hyundai      Accent  Hatchback    14.745     17.495   FWD       28
# 2           Kia         Rio      Sedan    13.990     18.290   FWD       28
# 3    Mitsubishi      Mirage  Hatchback    12.995     15.395   FWD       37
# 4        Nissan  Versa Note  Hatchback    14.180     17.960   FWD       31
# ..          ...         ...        ...       ...        ...   ...      ...
# 105      Toyoto     Sequioa      7Pass    44.395     64.320   RWD       12
# 106      Nissan  Pathfinder      7Pass    29.510     43.100   FWD       19
# 107       Acura         MDX      7Pass    42.865     57.080   FWD       18
# 108     Hyundai    Santa Fe      7Pass    30.150     36.000   FWD       18
# 109        GMC        Yukon      7Pass    47.740     67.520   RWD       16
#
# ...

# %%
car_by_make = cars['Model'].groupby(cars['Make']).count()

# %%
car_by_make.plot.pie(figsize =(10,10))

# %% [markdown]
# # Create csv file from the data below andread in pandas data frame

# %%
dataset = pd.read_csv('dataset/sample_data.csv')

# %%
dataset
# Out:
#      account_number                           name item_code category  \
# 0            296809                    Carroll PLC  QN-82852     Belt
# 1            563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt
# 2            758133      Kihn, McClure and Denesik  LL-46261    Shoes
# 3            563905  Kerluke, Reilly and Bechtelar  KV-99194    Shirt
# 4            758133      Kihn, McClure and Denesik  WJ-02096     Belt
# ..              ...                            ...       ...      ...
# 324          758133      Kihn, McClure and Denesik  LL-46261    Shoes
# 325          929400  Senger, Upton and Breitenberg  GS-86623    Shoes
# 326           98022              Heidenreich-Bosco  QN-82852     Belt
# 327          850140                      Kunze Inc  KV-99194    Shirt
# 328          758133      Kihn, McClure and Denesik  WJ-02096     Belt
#
#      quantity  unit price  net_price                       date   \
# ...

# %%
dataset.describe()
# Out:
#        account_number    quantity  unit price    net_price  Unnamed: 11  \
# count      329.000000  329.000000  329.000000   329.000000   244.000000
# mean    570173.082067   10.258359   55.494255   565.600152     9.963115
# std     245610.324363    5.442336   25.029363   406.797941     5.743727
# min      98022.000000    1.000000   10.120000    13.470000     1.000000
# 25%     299771.000000    6.000000   35.820000   237.720000     5.000000
# 50%     563905.000000   10.000000   56.630000   467.840000    10.000000
# 75%     758133.000000   15.000000   77.520000   859.770000    14.250000
# max     995267.000000   20.000000   99.880000  1912.000000    20.000000
#
#        Unnamed: 12  Unnamed: 13  Unnamed: 18  Unnamed: 19  Unnamed: 20  ...  \
# count   244.000000   244.000000   160.000000   160.000000    160.00000  ...
# mean     53.101066   539.027787    10.168750    61.672625    627.95100  ...
# std      26.144955   443.780580     5.774834    24.896986    459.30015  ...
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Columns: 113 entries, account_number to Unnamed: 112
# dtypes: float64(47), int64(2), object(64)
# memory usage: 290.6+ KB

# %% [markdown]
# # Create    new  dataframe  having  columns 'name','net_price' and  group  all  the records according to name

# %%
df = dataset[['name','net_price']].groupby('name')

# %%
df.size()
# Out:
# name
# Berge LLC                        28
# Carroll PLC                      33
# Cole-Eichmann                     2
# Davis, Kshlerin and Reilly       23
# Ernser, Cruickshank and Lind     24
# Gorczany-Hahn                     1
# Hamill-Hackett                    1
# Hegmann and Sons                 18
# Heidenreich-Bosco                 1
# Huel-Haag                         1
# Kerluke, Reilly and Bechtelar    23
# Kihn, McClure and Denesik        39
# Kilback-Gerlach                   2
# Koelpin PLC                      30
# Kunze Inc                        32
# Kuphal, Zieme and Kub            25
# Senger, Upton and Breitenberg    28
# Volkman, Goyette and Lemke       18
# dtype: int64

# %% [markdown]
# # Plot the graph after calculating total sales by each customer. Customer name should be on x axis and total sales in y axis.

# %%
sales = dataset[['name','net_price']].groupby('name').sum()

# %%
sales.plot(kind = 'bar')
